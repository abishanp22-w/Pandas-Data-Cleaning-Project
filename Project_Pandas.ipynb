# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/medical_insurance_uncleaned.csv')
df
# Out:
#       Claim_ID Patient_ID Policy_ID Hospital_ID   Name    Age  Gender  \
# 0      CLM1000    PAT5100   POL9291       HSP57    NaN   97.0       F
# 1      CLM1001    PAT7122   POL1727      HSP106  Priya   35.0       F
# 2      CLM1002    PAT7837   POL4305       HSP25   Amit   53.0    Male
# 3      CLM1003    PAT2862   POL1759      HSP498    NaN   33.0     Mle
# 4      CLM1004     PAT980   POL7294      HSP348   Ravi   -3.0  Female
# ...        ...        ...       ...         ...    ...    ...     ...
# 9995  CLM10995    PAT5719   POL6054       HSP97   Ravi   20.0  Female
# 9996  CLM10996    PAT2175   POL5818      HSP191   Amit   17.0  Female
# 9997  CLM10997    PAT2292   POL3010       HSP18   Mary  125.0  Female
# 9998  CLM10998    PAT5085   POL4118      HSP169   Ravi   23.0       F
# 9999  CLM10999     PAT479   POL5399      HSP203   Mary   58.0  Female
#
#                Email        Phone   Address  ... Deductible_Amount  \
# ...

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Claim_ID Patient_ID Policy_ID Hospital_ID   Name    Age  Gender  \
# 0      CLM1000    PAT5100   POL9291       HSP57    NaN   97.0       F
# 1      CLM1001    PAT7122   POL1727      HSP106  Priya   35.0       F
# 2      CLM1002    PAT7837   POL4305       HSP25   Amit   53.0    Male
# 3      CLM1003    PAT2862   POL1759      HSP498    NaN   33.0     Mle
# 4      CLM1004     PAT980   POL7294      HSP348   Ravi   -3.0  Female
# ...        ...        ...       ...         ...    ...    ...     ...
# 9995  CLM10995    PAT5719   POL6054       HSP97   Ravi   20.0  Female
# 9996  CLM10996    PAT2175   POL5818      HSP191   Amit   17.0  Female
# 9997  CLM10997    PAT2292   POL3010       HSP18   Mary  125.0  Female
# 9998  CLM10998    PAT5085   POL4118      HSP169   Ravi   23.0       F
# 9999  CLM10999     PAT479   POL5399      HSP203   Mary   58.0  Female
#
#                Email        Phone   Address  ... Deductible_Amount  \
# ...

# %%
df.duplicated(subset='Claim_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.drop_duplicates(subset='Claim_ID',inplace=True)
df
# Out:
#       Claim_ID Patient_ID Policy_ID Hospital_ID   Name    Age  Gender  \
# 0      CLM1000    PAT5100   POL9291       HSP57    NaN   97.0       F
# 1      CLM1001    PAT7122   POL1727      HSP106  Priya   35.0       F
# 2      CLM1002    PAT7837   POL4305       HSP25   Amit   53.0    Male
# 3      CLM1003    PAT2862   POL1759      HSP498    NaN   33.0     Mle
# 4      CLM1004     PAT980   POL7294      HSP348   Ravi   -3.0  Female
# ...        ...        ...       ...         ...    ...    ...     ...
# 9995  CLM10995    PAT5719   POL6054       HSP97   Ravi   20.0  Female
# 9996  CLM10996    PAT2175   POL5818      HSP191   Amit   17.0  Female
# 9997  CLM10997    PAT2292   POL3010       HSP18   Mary  125.0  Female
# 9998  CLM10998    PAT5085   POL4118      HSP169   Ravi   23.0       F
# 9999  CLM10999     PAT479   POL5399      HSP203   Mary   58.0  Female
#
#                Email        Phone   Address  ... Deductible_Amount  \
# ...

# %%
df.drop_duplicates(subset='Email',inplace=True)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID   Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57    NaN  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106  Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25   Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10    NaN  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284   Ravi  73.0  Other
#
#             Email        Phone   Address  ... Deductible_Amount  \
# 0           john@  98765 43210    Mumbai  ...            8962.0
# 1             NaN          NaN       NaN  ...           11878.0
# 2  amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7            ravi  98765 43210  New York  ...           17033.0
# 9  mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df["Name"] = df["Name"].fillna("Unknown")
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10  Unknown  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#             Email        Phone   Address  ... Deductible_Amount  \
# 0           john@  98765 43210    Mumbai  ...            8962.0
# 1             NaN          NaN       NaN  ...           11878.0
# 2  amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7            ravi  98765 43210  New York  ...           17033.0
# 9  mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df["Email"] = df["Email"].fillna("noemail@example.com")
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10  Unknown  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#                  Email        Phone   Address  ... Deductible_Amount  \
# 0                john@  98765 43210    Mumbai  ...            8962.0
# 1  noemail@example.com          NaN       NaN  ...           11878.0
# 2       amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7                 ravi  98765 43210  New York  ...           17033.0
# 9       mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df["Hospital_ID"] = df["Hospital_ID"].fillna("Not Available")
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10  Unknown  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#                  Email        Phone   Address  ... Deductible_Amount  \
# 0                john@  98765 43210    Mumbai  ...            8962.0
# 1  noemail@example.com          NaN       NaN  ...           11878.0
# 2       amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7                 ravi  98765 43210  New York  ...           17033.0
# 9       mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df["Insurance_Type"] = df["Insurance_Type"].fillna("General")
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10  Unknown  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#                  Email        Phone   Address  ... Deductible_Amount  \
# 0                john@  98765 43210    Mumbai  ...            8962.0
# 1  noemail@example.com          NaN       NaN  ...           11878.0
# 2       amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7                 ravi  98765 43210  New York  ...           17033.0
# 9       mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df["Claim_Amount"] = df.groupby("Disease_Category")["Claim_Amount"].transform(
    lambda x: x.fillna(x.mean())
)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10  Unknown  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#                  Email        Phone   Address  ... Deductible_Amount  \
# 0                john@  98765 43210    Mumbai  ...            8962.0
# 1  noemail@example.com          NaN       NaN  ...           11878.0
# 2       amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7                 ravi  98765 43210  New York  ...           17033.0
# 9       mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df["Approved_Amount"] = df.groupby("Insurance_Type")["Approved_Amount"].transform(
    lambda x: x.fillna(x.median())
)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 7  CLM1007    PAT2735   POL5797       HSP10  Unknown  20.0      F
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#                  Email        Phone   Address  ... Deductible_Amount  \
# 0                john@  98765 43210    Mumbai  ...            8962.0
# 1  noemail@example.com          NaN       NaN  ...           11878.0
# 2       amit@yahoo.com          NaN    Mumbai  ...           19973.0
# 7                 ravi  98765 43210  New York  ...           17033.0
# 9       mary@gmail.com          NaN       NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# ...

# %%
df.drop(df[df["Claim_Amount"] < 0].index,inplace=True)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID     Name   Age Gender  \
# 0  CLM1000    PAT5100   POL9291       HSP57  Unknown  97.0      F
# 1  CLM1001    PAT7122   POL1727      HSP106    Priya  35.0      F
# 2  CLM1002    PAT7837   POL4305       HSP25     Amit  53.0   Male
# 9  CLM1009    PAT1173   POL4586      HSP284     Ravi  73.0  Other
#
#                  Email        Phone Address  ... Deductible_Amount  \
# 0                john@  98765 43210  Mumbai  ...            8962.0
# 1  noemail@example.com          NaN     NaN  ...           11878.0
# 2       amit@yahoo.com          NaN  Mumbai  ...           19973.0
# 9       mary@gmail.com          NaN     NaN  ...               NaN
#
#   CoPay_Percentage Payment_Mode Payment_Status Reimbursement_Days  \
# 0             96.0         Cahs         Failed               57.0
# 1             21.0       Online         Failed               81.0
# 2             90.0         Card           Paid               62.0
# ...

# %%
df.drop(df[df["Approved_Amount"] > df["Claim_Amount"]].index,inplace=True)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID  Name   Age Gender  \
# 2  CLM1002    PAT7837   POL4305       HSP25  Amit  53.0   Male
# 9  CLM1009    PAT1173   POL4586      HSP284  Ravi  73.0  Other
#
#             Email Phone Address  ... Deductible_Amount CoPay_Percentage  \
# 2  amit@yahoo.com   NaN  Mumbai  ...           19973.0             90.0
# 9  mary@gmail.com   NaN     NaN  ...               NaN             47.0
#
#   Payment_Mode Payment_Status Reimbursement_Days Patient_Satisfaction_Score  \
# 2         Card           Paid               62.0                          3
# 9       Online        Pending               92.0                          3
#
#   Feedback Agent_Name Account_Status  Followup_Required
# 2     Good        Tom       Inactive                NaN
# 9     Good      Rahul         Active                 No
#
# [2 rows x 34 columns]

# %%
df.drop(df[(df["Age"] < 0) | (df["Age"] > 120)].index, inplace=True)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID  Name   Age Gender  \
# 2  CLM1002    PAT7837   POL4305       HSP25  Amit  53.0   Male
# 9  CLM1009    PAT1173   POL4586      HSP284  Ravi  73.0  Other
#
#             Email Phone Address  ... Deductible_Amount CoPay_Percentage  \
# 2  amit@yahoo.com   NaN  Mumbai  ...           19973.0             90.0
# 9  mary@gmail.com   NaN     NaN  ...               NaN             47.0
#
#   Payment_Mode Payment_Status Reimbursement_Days Patient_Satisfaction_Score  \
# 2         Card           Paid               62.0                          3
# 9       Online        Pending               92.0                          3
#
#   Feedback Agent_Name Account_Status  Followup_Required
# 2     Good        Tom       Inactive                NaN
# 9     Good      Rahul         Active                 No
#
# [2 rows x 34 columns]

# %%
df.drop(
    df[df["Treatment_End_Date"] < df["Treatment_Start_Date"]].index,inplace=True
)
df
# Out:
#   Claim_ID Patient_ID Policy_ID Hospital_ID  Name   Age Gender  \
# 2  CLM1002    PAT7837   POL4305       HSP25  Amit  53.0   Male
# 9  CLM1009    PAT1173   POL4586      HSP284  Ravi  73.0  Other
#
#             Email Phone Address  ... Deductible_Amount CoPay_Percentage  \
# 2  amit@yahoo.com   NaN  Mumbai  ...           19973.0             90.0
# 9  mary@gmail.com   NaN     NaN  ...               NaN             47.0
#
#   Payment_Mode Payment_Status Reimbursement_Days Patient_Satisfaction_Score  \
# 2         Card           Paid               62.0                          3
# 9       Online        Pending               92.0                          3
#
#   Feedback Agent_Name Account_Status  Followup_Required
# 2     Good        Tom       Inactive                NaN
# 9     Good      Rahul         Active                 No
#
# [2 rows x 34 columns]

# %%
df.drop(
    df[df["Policy_End_Date"] < df["Policy_Start_Date"]].index,
    inplace=True
)
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
df['Gender'].replace({'Mle':'Male','F':'Female','Fmale':'Female'},inplace=True)
# Out:
# /tmp/ipython-input-962020789.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'Mle':'Male','F':'Female','Fmale':'Female'},inplace=True)

# %%
df['Payment_Mode'].replace({'cahs':'cash'},inplace=True)
# Out:
# /tmp/ipython-input-391790804.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Payment_Mode'].replace({'cahs':'cash'},inplace=True)

# %%
df["Account_Status"] = df["Account_Status"].replace({"Active": "Active",
    "Act": "Active",
    "A": "Active",
    "Inactive": "Inactive",
    "Inact": "Inactive",
    "I": "Inactive",
    "Closed": "Closed",})
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
df['Deductible_Amount']=df['Deductible_Amount'].fillna('nan')
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
high_claims = df[df["Claim_Amount"] > 100000]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
rejected_claims = df[df["Claim_Status"] == "Rejected"]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
premium_claims = df[df["Insurance_Type"] == "Premium"]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
senior_patients = df[df["Age"] > 60]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
delayed_claims = df[df["Reimbursement_Days"] > 30]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
india_claims = df[df["Country"] == "India"]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
high_copay_claims = df[df["CoPay_Percentage"] > 20]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
poor_feedback_claims = df[df["Feedback"] == "Poor"]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
apollo_patients = df[df["Hospital_Name"] == "Apollo Hospital"]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
df[df["Treatment_End_Date"] - df["Treatment_Start_Date"] > pd.Timedelta(days=30)]
df
# Out:
# Empty DataFrame
# Columns: [Claim_ID, Patient_ID, Policy_ID, Hospital_ID, Name, Age, Gender, Email, Phone, Address, City, Country, Diagnosis, Disease_Category, Doctor_Name, Treatment_Start_Date, Treatment_End_Date, Hospital_Name, Insurance_Type, Claim_Amount, Approved_Amount, Claim_Status, Policy_Start_Date, Policy_End_Date, Deductible_Amount, CoPay_Percentage, Payment_Mode, Payment_Status, Reimbursement_Days, Patient_Satisfaction_Score, Feedback, Agent_Name, Account_Status, Followup_Required]
# Index: []
#
# [0 rows x 34 columns]

# %%
merged_df = merged_df[merged_df["Claim_Amount"] > 400]
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1788767078.py in <cell line: 0>()
# ----> 1 merged_df = merged_df[merged_df["Claim_Amount"] > 400]
#       2 merged_df
#
# NameError: name 'merged_df' is not defined

# %%
print(merged_df.columns)
print(hospitals.columns)

# %%
# If column has extra spaces
merged_df.columns = merged_df.columns.str.strip()
hospitals.columns = hospitals.columns.str.strip()

# %%
merged_df.rename(columns={'HospitalId': 'Hospital_ID'}, inplace=True)

# %%
merged_df.rename(columns={'Patient_ID': 'Hospital_ID'}, inplace=True)
merged_df = merged_df.merge(hospitals, on='Hospital_ID', how='left')
display(merged_df)

# %%
merged_df = insurance_df.merge(claims_df, on='Patient_ID')
display(merged_df)

# %%
total_claims = claims_df.merge(patients_df, on='Patient_ID') \
                        .groupby('Hospital_ID')['Claim_Amount'].sum() \
                        .reset_index()
display(total_claims)

# %%
average_approved = insurance_claims_df.groupby('Insurance_Type')['Approved_Amount'].mean().reset_index()
display(average_approved)

# %%
#coloumns[0]-hospital
#coloumns[1]-claim account
print(df.groupby(df.columns[0])[df.columns[1]].sum())

# %%
avg_approved = df.groupby('Insurance_Type')['Approved_Amount'].mean()
print(avg_approved)

# %%
print(df[df.duplicated(subset=['Patient_ID', 'Claim_Year'], keep=False)])

# %%
print(df.groupby(df.columns[0])[df.columns[1]].sum().sort_values(ascending=False).head(1))

# %%
only_rejected = df.groupby(df.columns[0])[df.columns[1]].apply(lambda x: (x == 'Rejected').all())
print(only_rejected[only_rejected].index)

# %%
missing_hospital = df[df[df.columns[0]].isna()]
print(missing_hospital)

# %%
missing_doctor = df[df[df.columns[1]].isna()]
print(missing_doctor)

# %%
df['Claim_Difference'] = df['Claim_Amount'] - df['Approved_Amount']
print(df)

# %%
df['Treatment_Duration'] = df['Treatment_End_Date'] - df['Treatment_Start_Date']
print(df)

# %%
df['Policy_Duration'] = df['Policy_End_Date'] - df['Policy_Start_Date']
print(df)

# %%
df['Age_Group'] = pd.cut(df['Age'], bins=[0, 17, 64, 150], labels=['Child', 'Adult', 'Senior'])
print(df)

# %%
df['Claim_Risk_Level'] = pd.cut(df['Claim_Amount'], bins=[-1,5000,10000,float('inf')], labels=['Low','Medium','High'])
print(df)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df['Gender_Code'] = df['Gender'].map({'Male': 1, 'Female': 0})
print(df)

# %%
df['Claim_Status_Code'] = df['Claim_Status'].map({'Approved': 1, 'Rejected': 0})
print(df)

# %%
df['Country'] = df['Country'].apply(lambda x: x.title() if x else x)
print(df)

# %%
df['Payment_Mode'] = df['Payment_Mode'].apply(lambda x: x.title() if x else x)
print(df)

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
print(df)

# %%
top_hospitals = df.groupby(df.columns[0])[df.columns[1]].sum().sort_values(ascending=False).head(10)
print(top_hospitals)

# %%
top_patients = df.groupby(df.columns[0])[df.columns[1]].sum().sort_values(ascending=False).head(10)
print(top_patients)

# %%
avg_claim = df.groupby(df.columns[0])[df.columns[1]].mean()
print(avg_claim)

# %%
avg_approved = df.groupby(df.columns[0])[df.columns[1]].mean()
print(avg_approved)

# %%
patients = df['Patient_ID'].value_counts()[lambda x: x > 3].index.tolist()
print(patients)

# %%
sorted_claims = df.sort_values('Claim_Difference', ascending=False)
print(sorted_claims)

# %%
total_claims = df.groupby(['Country','Insurance_Type'])['Claim_Amount'].sum()
print(total_claims)

# %%
invalid_claims = df[df['Approved_Amount'] > df['Claim_Amount']]
print(invalid_claims)

# %%
invalid_policies = df[df['Policy_Duration'] <= 0]
print(invalid_policies)

# %%
df['Error_Flag'] = df['Treatment_Duration'] > df['Policy_Duration']
print(df[df['Error_Flag']])

# %%
mismatches = df[(df['Age_Group'] == 'Child') & (df['Disease_Category'] == "Alzheimer's")]
print(mismatches)

# %%
invalid_phones = df[~df['Phone'].astype(str).str.fullmatch(r'\d{10}')]
print(invalid_phones)

# %%
df[df.filter(like='Date').columns] = df.filter(like='Date').apply(pd.to_datetime)
print(df)

# %%
df[['Email','Address']] = df[['Email','Address']].applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df['Doctor_Name'] = df['Doctor_Name'].str.title()
print(df)

# %%
outliers = df[df['CoPay_Percentage'] > 100]
print(outliers)

# %%
missing_payment = df[(df['Claim_Status'] == 'Completed') & (df['Payment_Status'].isna())]
print(missing_payment)
